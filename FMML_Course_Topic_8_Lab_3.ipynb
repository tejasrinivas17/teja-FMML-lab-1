# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasrinivas17/teja-FMML-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-31 14:42:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   222MB/s    in 0.3s
#
# 2023-05-31 14:42:17 (222 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 113    1605.07427v1  Memory networks are neural networks with an ex...  stat
# 17376  1710.08451v1  The importance of building sentiment analysis ...    cs
# 6902   1707.03538v1  Mixture-of-experts (MoE) models are a powerful...  stat
# 4048    1107.1470v2  The paper deals with the error analysis of a n...    cs
# 10117  1706.09520v6  We present an approach for agents to learn rep...    cs
# ...             ...                                                ...   ...
# 5874    1206.6863v1  We show that the multi-class support vector ma...    cs
# 1140   1802.09405v1  Graph neural networks (GNNs) are a class of ne...    cs
# 34768  1802.03606v1  In this paper we present the performance of pa...    cs
# 10583   1309.3233v1  Decomposing tensors into orthogonal factors is...  stat
# 365    1712.02734v2  With access to large datasets, deep neural net...  stat
#
#                                                    title  year  \
# 113                         Hierarchical Memory Networks  2016
# 17376  Combining Lexical Features and a Supervised Le...  2017
# 6902   An Introduction to the Practical and Theoretic...  2017
# 4048   Vision-Based Navigation II: Error Analysis for...  2011
# 10117  Neural SLAM: Learning to Explore with External...  2017
# ...                                                  ...   ...
# 5874      Bayesian Multicategory Support Vector Machines  2012
# 1140   Improving Graph Convolutional Networks with No...  2018
# 34768                                    Distributed NLP  2018
# 10583  Efficient Orthogonal Tensor Decomposition, wit...  2013
# 365    Using Rule-Based Labels for Weak Supervised Le...  2017
#
#                                                 keywords
# 113    [component, addressed, backpropagation, comput...
# 17376  [importance, sentiment, recognized, especially...
# 6902   [generating, processes, demonstrate, different...
# 4048   [navigation, algorithm, straightforward, resol...
# 10117  [representations, exploration, environments, p...
# ...                                                  ...
# 5874   [estimation, procedure, appropriate, probabili...
# 1140   [efficiently, inference, associated, structure...
# 34768  [performance, processing, scientific, processe...
# 10583  [decomposing, orthogonal, statistics, processi...
# 365    [recognition, chemistry, inherently, fragmente...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 113      [component, addressed, backpropagation, comput...
# 17376    [importance, sentiment, recognized, especially...
# 6902     [generating, processes, demonstrate, different...
# 4048     [navigation, algorithm, straightforward, resol...
# 10117    [representations, exploration, environments, p...
#                                ...
# 37073    [understand, centrality, multiplex, centrality...
# 6909     [different, inference, approaches, factorisati...
# 40951    [effective, efficient, detection, alzheimers, ...
# 12214    [witnessed, successful, application, challengi...
# 28580    [researchers, pulmonary, available, different,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8809 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="430bd090-4524-4785-a366-06740811b5bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("430bd090-4524-4785-a366-06740811b5bc")) {                    Plotly.newPlot(                        "430bd090-4524-4785-a366-06740811b5bc",                        [{"x":["answering","attention","reinforcement","specifically","mechanisms","organized","computationally","hierarchical","procedures","extremely","considered","successfully","backpropagation","techniques","inference","approximate","challenging","computation","incorporate","applications","addressed","structure","component","importance","combining","colloquial","increased","experimented","benchmarked","presented","integrated","supervised","sentiment","difficulties","recognized","developed","available","especially","platforms","components","consistent","demonstrate","different","constructing","clustering","theoretical","regression","estimators","probabilistic","information","arbitrary","algorithms","likelihood","conditions","illustrate","estimating","constructed","blockwise","parameters","obtaining","criterion","classification","introduction","underlying","practical","justification","framework","estimator","generating","asymptotically","processes","derivation","algorithm","trajectory","resolution","expression","measurements","mentioned","straightforward","characterizing","navigation","differentiable","essential","environments","encourages","architectures","preliminary","exploration","environment","addressing","localization","simultaneous","experiments","behaviors","representations","representation","traditional","completely","evolution","mimicking","estimated","continuous","statistics","optimization","distributions","generated","functions","investigates","differential","iterative","sequences","stochastic","equations","paradigms","asymptotic","objective","evolutions","iterations","computational","accelerated","statistical","behaviour","exponential","efficiency","convolutional","complexity","intrinsically","modalities","transmission","reasoning","maximisation","definition","optimisation","artificial","motivated","variational","maximising","empowerment","precision","prediction","denoising","recovering","relevance","simulations","construct","symmetric","improvement","typically","simultaneously","structures","correspond","performance","efficient","corrupted","constrained","reconstruction","relaxation","effectiveness","confidence","reformulation","formulate","synthetic","alternative","frameworks","simulation","generator","hyperbolic","vanishing","approximation","activation","normalization","activations","modification","quadratic","constraint","accuracies","hypothetical","calibration","important","education","unsupervised","bottlenecks","classifier","departments","bottleneck","automated","therefore","california","attrition","predicting","desirable","university","syllables","parameter","distinguishing","piecewise","relationship","previously","character","hypothesis"],"y":[56,161,106,168,46,25,83,123,41,47,128,91,24,360,186,115,271,151,68,441,31,340,107,87,110,2,39,9,6,188,55,194,35,25,17,209,295,112,31,105,86,576,758,36,149,140,125,12,150,679,96,625,68,113,67,63,62,0,231,44,54,450,26,113,123,5,568,28,87,13,110,14,822,24,106,42,47,17,30,22,29,38,78,90,14,120,51,56,118,22,59,30,588,22,254,363,172,32,61,5,57,112,61,333,122,174,212,27,37,80,99,129,25,14,17,174,3,28,276,16,173,31,49,149,359,228,5,38,15,126,1,31,24,134,64,52,0,0,82,240,34,23,22,56,113,25,153,117,114,147,29,891,435,21,58,105,18,215,39,2,56,119,108,33,82,28,1,17,110,31,35,22,21,27,103,19,4,21,354,10,134,6,142,2,15,89,129,1,1,67,36,8,3,146,17,22,70,94,56,60],"type":"bar"},{"x":["answering","attention","reinforcement","specifically","mechanisms" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Partial</span> <span style=''>light</span> <span style=''>field</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>tomographic</span> <span style='background-color:rgba(0, 255, 0, 0.47887323943661975);'>reconstruction</span> <span style=''>from</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>camera</span> <span style=''>focal</span> <span style=''>stack</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.4727272727272728);'>describes</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reconstruct</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5703703703703704);'>resolution</span> <span style=''>4D</span> <span style=''>light</span> <span style=''>fields</span> <span style=''>from</span> <span style=''>a</span> <span style=''>stack</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3043478260869567);'>differently</span> <span style=''>focused</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>photographs</span> <span style=''>taken</span> <span style=''>with</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>camera</span> <span style=''>First</span> <span style=''>a</span> <span style=''>focus</span> <span style=''>map</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calculated</span> <span style=''>from</span> <span style=''>this</span> <span style=''>stack</span> <span style=''>using</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.34146341463414637);'>combining</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.5023255813953489);'>detection</span> <span style=''>and</span> <span style=''>region</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>with</span> <span style=''>graph</span> <span style=''>cut</span> <span style=''>Then</span> <span style=''>this</span> <span style=''>focus</span> <span style=''>map</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>converted</span> <span style=''>into</span> <span style=''>a</span> <span style=''>depth</span> <span style=''>map</span> <span style=''>thanks</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibration</span> <span style=''>of</span> <span style=''>the</span> <span style=''>camera</span> <span style=''>We</span> <span style=''>proceed</span> <span style=''>after</span> <span style=''>this</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>tomographic</span> <span style='background-color:rgba(0, 255, 0, 0.47887323943661975);'>reconstruction</span> <span style=''>of</span> <span style=''>the</span> <span style=''>epipolar</span> <span style=''>images</span> <span style=''>by</span> <span style=''>back</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projecting</span> <span style=''>the</span> <span style=''>focused</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>scene</span> <span style=''>only</span> <span style=''>We</span> <span style=''>call</span> <span style=''>it</span> <span style=''>masked</span> <span style=''>back</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>The</span> <span style=''>angles</span> <span style=''>of</span> <span style=''>back</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>are</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style=''>Non</span> <span style=''>Negative</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>A</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalence</span> <span style=''>between</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>(NMF)</span> <span style=''>and</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>As</span> <span style=''>NMF</span> <span style=''>and</span> <span style=''>many</span> <span style=''>of</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style=''>linear</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>NMF</span> <span style=''>with</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonality</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>general</span> <span style=''>kernel</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiplicative</span> <span style=''>update</span> <span style=''>rules</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>problem</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style=''>NMF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>two</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>named</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>KNSC</span> <span style=''>Ncut</span> <span style=''>and</span> <span style=''>KNSC</span> <span style=''>Rcut</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>with</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style=''>cut</span> <span style=''>and</span> <span style=''>ratio</span> <span style=''>cut</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>We</span> <span style=''>further</span> <span style=''>extend</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.320754716981132);'>relaxation</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3541666666666665);'>inference</span> <span style=''>in</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>the</span> <span style=''>most</span> <span style=''>probable</span> <span style=''>state</span> <span style=''>of</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>field</span> <span style=''>(MRF)</span> <span style=''>also</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style=''>MRF</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>The</span> <span style=''>task</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>NP</span> <span style=''>hard</span> <span style=''>in</span> <span style=''>general</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivates</span> <span style=''>numerous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>submodular</span> <span style='background-color:rgba(255, 0, 0, 0.320754716981132);'>relaxation</span> <span style=''>approach</span> <span style=''>(SMR)</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Lagrangian</span> <span style='background-color:rgba(255, 0, 0, 0.320754716981132);'>relaxation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>problem</span> <span style=''>Unlike</span> <span style=''>the</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>approach</span> <span style=''>of</span> <span style=''>Komodakis</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2011</span> <span style=''>SMR</span> <span style=''>does</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decompose</span> <span style=''>the</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>problem</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>constructs</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>submodular</span> <span style=''>energy</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>minimized</span> <span style=''>within</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Lagrangian</span> <span style='background-color:rgba(255, 0, 0, 0.320754716981132);'>relaxation</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicable</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>To</span> <span style=''>prune</span> <span style=''>or</span> <span style=''>not</span> <span style=''>to</span> <span style=''>prune</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploring</span> <span style=''>the</span> <span style=''>efficacy</span> <span style=''>of</span> <span style=''>pruning</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <br/><br/><span style=''>Model</span> <span style=''>pruning</span> <span style=''>seeks</span> <span style=''>to</span> <span style=''>induce</span> <span style=''>sparsity</span> <span style=''>in</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>matrices</span> <span style=''>thereby</span> <span style=''>reducing</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>nonzero</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style=''>Recent</span> <span style=''>reports</span> <span style=''>(Han</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015</span> <span style=''>Narang</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2017)</span> <span style=''>prune</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>at</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>only</span> <span style=''>a</span> <span style=''>marginal</span> <span style=''>loss</span> <span style=''>in</span> <span style=''>accuracy</span> <span style=''>and</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>sizable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>in</span> <span style=''>model</span> <span style=''>size</span> <span style=''>This</span> <span style=''>hints</span> <span style=''>at</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>possibility</span> <span style=''>that</span> <span style=''>the</span> <span style=''>baseline</span> <span style=''>models</span> <span style=''>in</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>are</span> <span style=''>perhaps</span> <span style=''>severely</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style=''>at</span> <span style=''>the</span> <span style=''>outset</span> <span style=''>and</span> <span style=''>a</span> <span style=''>viable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>for</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style=''>might</span> <span style=''>be</span> <span style=''>to</span> <span style=''>simply</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>hidden</span> <span style=''>units</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>the</span> <span style=''>models</span> <span style=''>dense</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>exposing</span> <span style=''>a</span> <span style=''>similar</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>in</span> <span style=''>model</span> <span style=''>size</span> <span style=''>and</span> <span style=''>accuracy</span> <span style=''>We< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0688547984302533)
# 	representation (0.12950410274705673)
# 	processing (0.10096325365679629)
# 	segmentation (0.0720656439529076)
# 	information (0.24224045665358546)
# 	experimental (0.14341776667855868)
# 	detection (0.11523367820192651)
# 	recognition (0.12522297538351765)
# 	different (0.27042454513021763)
# 	convolutional (0.1280770602925437)
#
# Some Statistics words are:
# 	stochastic (0.1357035553329995)
# 	variables (0.1402103154732098)
# 	theoretical (0.14321482223335003)
# 	estimation (0.17376064096144217)
# 	statistical (0.157235853780671)
# 	algorithm (0.4046069103655483)
# 	dimensional (0.18227341011517276)
# 	inference (0.19529293940911366)
# 	distribution (0.19829744616925388)
# 	regression (0.17876815222834253)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a4a3ec6c-bad1-4e6e-80fd-1633489e85d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4a3ec6c-bad1-4e6e-80fd-1633489e85d6")) {                    Plotly.newPlot(                        "a4a3ec6c-bad1-4e6e-80fd-1633489e85d6",                        [{"x":["answering","attention","reinforcement","specifically","mechanisms","organized","computationally","hierarchical","procedures","extremely","considered","successfully","backpropagation","techniques","inference","approximate","challenging","computation","incorporate","applications","addressed","structure","component","importance","combining","colloquial","increased","experimented","benchmarked","presented","integrated","supervised","sentiment","difficulties","recognized","developed","available","especially","platforms","components","consistent","demonstrate","different","constructing","clustering","theoretical","regression","estimators","probabilistic","information","arbitrary","algorithms","likelihood","conditions","illustrate","estimating","constructed","blockwise","parameters","obtaining","criterion","classification","introduction","underlying","practical","justification","framework","estimator","generating","asymptotically","processes","derivation","algorithm","trajectory","resolution","expression","measurements","mentioned","straightforward","characterizing","navigation","differentiable","essential","environments","encourages","architectures","preliminary","exploration","environment","addressing","localization","simultaneous","experiments","behaviors","representations","representation","traditional","completely","evolution","mimicking","estimated","continuous","statistics","optimization","distributions","generated","functions","investigates","differential","iterative","sequences","stochastic","equations","paradigms","asymptotic","objective","evolutions","iterations","computational","accelerated","statistical","behaviour","exponential","efficiency","convolutional","complexity","intrinsically","modalities","transmission","reasoning","maximisation","definition","optimisation","artificial","motivated","variational","maximising","empowerment","precision","prediction","denoising","recovering","relevance","simulations","construct","symmetric","improvement","typically","simultaneously","structures","correspond","performance","efficient","corrupted","constrained","reconstruction","relaxation","effectiveness","confidence","reformulation","formulate","synthetic","alternative","frameworks","simulation","generator","hyperbolic","vanishing","approximation","activation","normalization","activations","modification","quadratic","constraint","accuracies","hypothetical","calibration","important","education","unsupervised","bottlenecks","classifier","departments","bottleneck","automated","therefore","california","attrition","predicting","desirable","university","syllables","parameter","distinguishing","piecewise","relationship","previously","character","hypothesis","characters","distribution","logarithmic","empirically","knowledge","collaborative","approaches","questions","associations","forgetting","intrinsic","assessment","comparable","difficulty","transitions","personalized","organization","analytics","unobserved","responses","analyzing","quantities","estimates","interacting","filtering","resources","experimental","forecasts","congestion","facilities","constraints","congested","approximations","investigate","assistants","conducted","theoretic","influences","smoothing","predictive","dynamical","equilibria","customers","assistant","baselines","coordination","application","detection","experimentally","validations","biomarkers","robustness","comprising","segmentation","automatic","automatically","predi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	blockwise
# 	maximising
# 	empowerment
# 	imputations
# 	astrophysics
# 	microwave
# 	minimises
# 	collinearity
# 	diverging
# 	recursion
# 	parallelize
# 	accompanies
# 	mcallester
# 	kontorovich
# 	exponents
# 	purchases
# 	mapreduce
# 	subpopulation
# 	subpopulations
# 	neuroscientists
# Some words which never appear in Statistics papers:
# 	colloquial
# 	experimented
# 	navigation
# 	syllables
# 	congested
# 	assistant
# 	validations
# 	adjustment
# 	endeavors
# 	photography
# 	programmed
# 	curriculum
# 	enriching
# 	submitted
# 	predicate
# 	translators
# 	paraconsistent
# 	readwrite
# 	attractiveness
# 	keyframes

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067955207853966e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
